# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | aykhal
# Processing Record 2 of Set 1 | avarua
# Processing Record 3 of Set 1 | ust-kuyga
# Processing Record 4 of Set 1 | morondava
# Processing Record 5 of Set 1 | tuktoyaktuk
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | georgetown
# Processing Record 9 of Set 1 | cuamba
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | artyk
# City not found. Skipping...
# Processing Record 12 of Set 1 | port macquarie
# Processing Record 13 of Set 1 | jardim
# Processing Record 14 of Set 1 | guerrero negro
# Processing Record 15 of Set 1 | canberra
# Processing Record 16 of Set 1 | wexford
# Processing Record 17 of Set 1 | tongren
# Processing Record 18 of Set 1 | mahebourg
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | hirara
# Processing Record 22 of Set 1 | lebu
# Processing Record 23 of Set 1 | tasiilaq
# Processing Record 24 of Set 1 | coahuayana
# Processing Record 25 of Set 1 | roebourne
# Processing Record 26 of Set 1 | havelock
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | pundaguitan
# Processing Record 29 of Set 1 | kalmunai
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | kodiak
# Processing Record 32 of Set 1 | qaanaaq
# Processing Record 33 of Set 1 | rocha
# Processing Record 34 of Set 1 | tulum
# Processing Record 35 of Set 1 | ambodifototra
# City not found. Skipping...
# Processing Record 36 of Set 1 | posse
# Processing Record 37 of Set 1 | knokke-heist
# Processing Record 38 of Set 1 | saquena
# Processing Record 39 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 40 of Set 1 | bethanien
# Processing Record 41 of Set 1 | sao felix do xingu
# Processing Record 42 of Set 1 | atuona
# Processing Record 43 of Set 1 | padang
# Processing Record 44 of Set 1 | praia
# Processing Record 45 of Set 1 | hermanus
# Processing Record 46 of Set 1 | rikitea
# Processing Record 47 of Set 1 | pedernales
# Processing Record 48 of Set 1 | paradwip
# City not found. Skipping...
# Processing Record 49 of Set 1 | albany
# Processing Record 50 of Set 1 | kruisfontein
# Processing Record 1 of Set 2 | katsuura
# Processing Record 2 of Set 2 | nikolskoye
# Processing Record 3 of Set 2 | saskylakh
# Processing Record 4 of Set 2 | suntar
# Processing Record 5 of Set 2 | kahului
# Processing Record 6 of Set 2 | arraial do cabo
# Processing Record 7 of Set 2 | bluff
# Processing Record 8 of Set 2 | kichera
# Processing Record 9 of Set 2 | saint-philippe
# Processing Record 10 of Set 2 | torbay
# Processing Record 11 of Set 2 | avera
# Processing Record 12 of Set 2 | east london
# Processing Record 13 of Set 2 | muyezerskiy
# Processing Record 14 of Set 2 | bredy
# Processing Record 15 of Set 2 | milkovo
# Processing Record 16 of Set 2 | novorudnyy
# Processing Record 17 of Set 2 | bengkulu
# Processing Record 18 of Set 2 | new norfolk
# Processing Record 19 of Set 2 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 20 of Set 2 | bundaberg
# Processing Record 21 of Set 2 | barrow
# Processing Record 22 of Set 2 | dikson
# Processing Record 23 of Set 2 | gari
# Processing Record 24 of Set 2 | letpadan
# Processing Record 25 of Set 2 | hofn
# Processing Record 26 of Set 2 | abu dhabi
# Processing Record 27 of Set 2 | lavrentiya
# Processing Record 28 of Set 2 | jamestown
# Processing Record 29 of Set 2 | port hedland
# Processing Record 30 of Set 2 | hobart
# Processing Record 31 of Set 2 | longyearbyen
# Processing Record 32 of Set 2 | arman
# Processing Record 33 of Set 2 | kalakamati
# Processing Record 34 of Set 2 | severo-kurilsk
# Processing Record 35 of Set 2 | broome
# Processing Record 36 of Set 2 | cidreira
# Processing Record 37 of Set 2 | ushuaia
# Processing Record 38 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 39 of Set 2 | phan rang
# City not found. Skipping...
# Processing Record 40 of Set 2 | hasaki
# Processing Record 41 of Set 2 | yuancheng
# Processing Record 42 of Set 2 | san patricio
# Processing Record 43 of Set 2 | azimur
# City not found. Skipping...
# Processing Record 44 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 2 | gamba
# Processing Record 46 of Set 2 | busselton
# Processing Record 47 of Set 2 | monkey bay
# Processing Record 48 of Set 2 | cherskiy
# Processing Record 49 of Set 2 | coquimbo
# Processing Record 50 of Set 2 | hervey bay
# Processing Record 1 of Set 3 | thompson
# Processing Record 2 of Set 3 | angoche
# Processing Record 3 of Set 3 | lianran
# Processing Record 4 of Set 3 | mar del plata
# Processing Record 5 of Set 3 | cabo san lucas
# Processing Record 6 of Set 3 | yar-sale
# Processing Record 7 of Set 3 | huarmey
# Processing Record 8 of Set 3 | pangnirtung
# Processing Record 9 of Set 3 | balabac
# Processing Record 10 of Set 3 | beloha
# Processing Record 11 of Set 3 | tiznit
# Processing Record 12 of Set 3 | sao filipe
# Processing Record 13 of Set 3 | cherepovets
# Processing Record 14 of Set 3 | berlevag
# Processing Record 15 of Set 3 | luocheng
# Processing Record 16 of Set 3 | lazaro cardenas
# Processing Record 17 of Set 3 | bambous virieux
# Processing Record 18 of Set 3 | lampazos de naranjo
# Processing Record 19 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 3 | kushima
# Processing Record 21 of Set 3 | norman wells
# Processing Record 22 of Set 3 | saldanha
# Processing Record 23 of Set 3 | chuy
# Processing Record 24 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 3 | constitucion
# Processing Record 26 of Set 3 | ahipara
# Processing Record 27 of Set 3 | zakharo
# City not found. Skipping...
# Processing Record 28 of Set 3 | basco
# Processing Record 29 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 3 | cockburn town
# Processing Record 31 of Set 3 | mackay
# Processing Record 32 of Set 3 | bethel
# Processing Record 33 of Set 3 | honiara
# Processing Record 34 of Set 3 | umm lajj
# Processing Record 35 of Set 3 | samarai
# Processing Record 36 of Set 3 | asau
# Processing Record 37 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 3 | kudahuvadhoo
# Processing Record 39 of Set 3 | narsaq
# Processing Record 40 of Set 3 | fortuna
# Processing Record 41 of Set 3 | bhubaneswar
# Processing Record 42 of Set 3 | razole
# Processing Record 43 of Set 3 | fort frances
# Processing Record 44 of Set 3 | sola
# Processing Record 45 of Set 3 | obo
# Processing Record 46 of Set 3 | ribeira grande
# Processing Record 47 of Set 3 | lima
# Processing Record 48 of Set 3 | saint-pierre
# Processing Record 49 of Set 3 | touros
# Processing Record 50 of Set 3 | los llanos de aridane
# Processing Record 1 of Set 4 | butaritari
# Processing Record 2 of Set 4 | carnarvon
# Processing Record 3 of Set 4 | andijon
# Processing Record 4 of Set 4 | krasnorechenskiy
# Processing Record 5 of Set 4 | carlsbad
# Processing Record 6 of Set 4 | hualmay
# Processing Record 7 of Set 4 | bredasdorp
# Processing Record 8 of Set 4 | luena
# Processing Record 9 of Set 4 | port alfred
# Processing Record 10 of Set 4 | lompoc
# Processing Record 11 of Set 4 | meulaboh
# Processing Record 12 of Set 4 | brainerd
# Processing Record 13 of Set 4 | bathsheba
# Processing Record 14 of Set 4 | luanda
# Processing Record 15 of Set 4 | tecolutla
# Processing Record 16 of Set 4 | mount gambier
# Processing Record 17 of Set 4 | karratha
# Processing Record 18 of Set 4 | tautira
# Processing Record 19 of Set 4 | cumaribo
# City not found. Skipping...
# Processing Record 20 of Set 4 | soyo
# Processing Record 21 of Set 4 | cilegon
# Processing Record 22 of Set 4 | marawi
# Processing Record 23 of Set 4 | krasnoyarskiy
# Processing Record 24 of Set 4 | khatanga
# Processing Record 25 of Set 4 | goianapolis
# Processing Record 26 of Set 4 | kangar
# Processing Record 27 of Set 4 | aitape
# Processing Record 28 of Set 4 | nome
# Processing Record 29 of Set 4 | yashalta
# Processing Record 30 of Set 4 | mount isa
# Processing Record 31 of Set 4 | palm bay
# Processing Record 32 of Set 4 | sechura
# Processing Record 33 of Set 4 | kirkenaer
# Processing Record 34 of Set 4 | gizo
# Processing Record 35 of Set 4 | liverpool
# Processing Record 36 of Set 4 | vanimo
# Processing Record 37 of Set 4 | alamogordo
# Processing Record 38 of Set 4 | waverly
# Processing Record 39 of Set 4 | yagodnoye
# Processing Record 40 of Set 4 | kysyl-syr
# Processing Record 41 of Set 4 | san policarpo
# Processing Record 42 of Set 4 | ibadan
# Processing Record 43 of Set 4 | provideniya
# Processing Record 44 of Set 4 | kachikau
# City not found. Skipping...
# Processing Record 45 of Set 4 | loubomo
# Processing Record 46 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 4 | upernavik
# Processing Record 48 of Set 4 | leninogorsk
# Processing Record 49 of Set 4 | estelle
# Processing Record 50 of Set 4 | hovd
# Processing Record 1 of Set 5 | keflavik
# Processing Record 2 of Set 5 | iqaluit
# Processing Record 3 of Set 5 | buy
# Processing Record 4 of Set 5 | margate
# Processing Record 5 of Set 5 | kaitangata
# Processing Record 6 of Set 5 | cizre
# Processing Record 7 of Set 5 | nanortalik
# Processing Record 8 of Set 5 | cape town
# Processing Record 9 of Set 5 | kavieng
# Processing Record 10 of Set 5 | kiunga
# Processing Record 11 of Set 5 | hithadhoo
# Processing Record 12 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 5 | luderitz
# Processing Record 14 of Set 5 | puerto colombia
# Processing Record 15 of Set 5 | teguise
# Processing Record 16 of Set 5 | olafsvik
# Processing Record 17 of Set 5 | neiafu
# Processing Record 18 of Set 5 | tiksi
# Processing Record 19 of Set 5 | pevek
# Processing Record 20 of Set 5 | novotitarovskaya
# Processing Record 21 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 5 | eyl
# Processing Record 23 of Set 5 | atambua
# Processing Record 24 of Set 5 | komatipoort
# Processing Record 25 of Set 5 | mizan teferi
# Processing Record 26 of Set 5 | saint george
# Processing Record 27 of Set 5 | laguna
# Processing Record 28 of Set 5 | tshane
# Processing Record 29 of Set 5 | ejura
# Processing Record 30 of Set 5 | haines junction
# Processing Record 31 of Set 5 | karasjok
# Processing Record 32 of Set 5 | talnakh
# Processing Record 33 of Set 5 | yelizovo
# Processing Record 34 of Set 5 | lasa
# Processing Record 35 of Set 5 | boo
# Processing Record 36 of Set 5 | shingu
# Processing Record 37 of Set 5 | pietersburg
# Processing Record 38 of Set 5 | adrar
# Processing Record 39 of Set 5 | karera
# Processing Record 40 of Set 5 | fukue
# Processing Record 41 of Set 5 | kloulklubed
# Processing Record 42 of Set 5 | sobolevo
# Processing Record 43 of Set 5 | hailey
# Processing Record 44 of Set 5 | mugumu
# Processing Record 45 of Set 5 | te anau
# Processing Record 46 of Set 5 | qingdao
# Processing Record 47 of Set 5 | kesennuma
# City not found. Skipping...
# Processing Record 48 of Set 5 | sur
# Processing Record 49 of Set 5 | acapulco
# Processing Record 50 of Set 5 | radeberg
# Processing Record 1 of Set 6 | ponta do sol
# Processing Record 2 of Set 6 | vila franca do campo
# Processing Record 3 of Set 6 | taltal
# Processing Record 4 of Set 6 | chama
# Processing Record 5 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 6 | yanchukan
# City not found. Skipping...
# Processing Record 7 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 6 | knysna
# Processing Record 9 of Set 6 | sakaiminato
# Processing Record 10 of Set 6 | souillac
# Processing Record 11 of Set 6 | ucluelet
# Processing Record 12 of Set 6 | bayji
# Processing Record 13 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 14 of Set 6 | panixtlahuaca
# City not found. Skipping...
# Processing Record 15 of Set 6 | nemuro
# Processing Record 16 of Set 6 | kasongo-lunda
# Processing Record 17 of Set 6 | chicama
# Processing Record 18 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 6 | khandyga
# Processing Record 21 of Set 6 | zhezkazgan
# Processing Record 22 of Set 6 | esperance
# Processing Record 23 of Set 6 | champerico
# Processing Record 24 of Set 6 | makungu
# Processing Record 25 of Set 6 | shimoda
# Processing Record 26 of Set 6 | dutlwe
# Processing Record 27 of Set 6 | hami
# Processing Record 28 of Set 6 | dakar
# Processing Record 29 of Set 6 | shellbrook
# Processing Record 30 of Set 6 | geraldton
# Processing Record 31 of Set 6 | ptichye
# Processing Record 32 of Set 6 | oranjestad
# Processing Record 33 of Set 6 | bonavista
# Processing Record 34 of Set 6 | maragheh
# Processing Record 35 of Set 6 | henties bay
# Processing Record 36 of Set 6 | erenhot
# Processing Record 37 of Set 6 | yola
# Processing Record 38 of Set 6 | zhigansk
# Processing Record 39 of Set 6 | grindavik
# Processing Record 40 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 6 | mekhe
# Processing Record 42 of Set 6 | turukhansk
# Processing Record 43 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 6 | vanavara
# Processing Record 45 of Set 6 | bakel
# Processing Record 46 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 6 | ahuimanu
# Processing Record 48 of Set 6 | luangwa
# Processing Record 49 of Set 6 | victoria
# Processing Record 50 of Set 6 | erzin
# Processing Record 1 of Set 7 | novoagansk
# Processing Record 2 of Set 7 | berbera
# Processing Record 3 of Set 7 | sazonovo
# Processing Record 4 of Set 7 | benicarlo
# Processing Record 5 of Set 7 | taoudenni
# Processing Record 6 of Set 7 | lagoa
# Processing Record 7 of Set 7 | teya
# Processing Record 8 of Set 7 | lorengau
# Processing Record 9 of Set 7 | tawnat
# City not found. Skipping...
# Processing Record 10 of Set 7 | namibe
# Processing Record 11 of Set 7 | johnstown
# Processing Record 12 of Set 7 | constantine
# Processing Record 13 of Set 7 | itoman
# Processing Record 14 of Set 7 | yarada
# Processing Record 15 of Set 7 | bjerkvik
# Processing Record 16 of Set 7 | shubarshi
# Processing Record 17 of Set 7 | mwense
# Processing Record 18 of Set 7 | vestmanna
# Processing Record 19 of Set 7 | bhandaria
# Processing Record 20 of Set 7 | chokurdakh
# Processing Record 21 of Set 7 | hailar
# Processing Record 22 of Set 7 | colesberg
# Processing Record 23 of Set 7 | comodoro rivadavia
# Processing Record 24 of Set 7 | north auburn
# Processing Record 25 of Set 7 | teahupoo
# Processing Record 26 of Set 7 | makung
# City not found. Skipping...
# Processing Record 27 of Set 7 | hobyo
# Processing Record 28 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 7 | yumen
# Processing Record 30 of Set 7 | vardo
# Processing Record 31 of Set 7 | guntakal
# Processing Record 32 of Set 7 | tolaga bay
# Processing Record 33 of Set 7 | half moon bay
# Processing Record 34 of Set 7 | jutai
# Processing Record 35 of Set 7 | kracheh
# City not found. Skipping...
# Processing Record 36 of Set 7 | zachagansk
# City not found. Skipping...
# Processing Record 37 of Set 7 | airai
# Processing Record 38 of Set 7 | poya
# Processing Record 39 of Set 7 | vranestica
# Processing Record 40 of Set 7 | ishigaki
# Processing Record 41 of Set 7 | mangan
# Processing Record 42 of Set 7 | fort nelson
# Processing Record 43 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 44 of Set 7 | teguldet
# Processing Record 45 of Set 7 | kulhudhuffushi
# Processing Record 46 of Set 7 | christchurch
# Processing Record 47 of Set 7 | manta
# Processing Record 48 of Set 7 | nalut
# Processing Record 49 of Set 7 | beringovskiy
# Processing Record 50 of Set 7 | payson
# Processing Record 1 of Set 8 | buraydah
# Processing Record 2 of Set 8 | alice springs
# Processing Record 3 of Set 8 | pafos
# Processing Record 4 of Set 8 | conakry
# Processing Record 5 of Set 8 | vila do maio
# Processing Record 6 of Set 8 | sibu
# Processing Record 7 of Set 8 | derzhavinsk
# Processing Record 8 of Set 8 | porto novo
# Processing Record 9 of Set 8 | high level
# Processing Record 10 of Set 8 | agboville
# Processing Record 11 of Set 8 | klaksvik
# Processing Record 12 of Set 8 | nantucket
# Processing Record 13 of Set 8 | qui nhon
# Processing Record 14 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 15 of Set 8 | kasempa
# Processing Record 16 of Set 8 | yulara
# Processing Record 17 of Set 8 | egvekinot
# Processing Record 18 of Set 8 | brae
# Processing Record 19 of Set 8 | opuwo
# Processing Record 20 of Set 8 | srednekolymsk
# Processing Record 21 of Set 8 | cathedral city
# Processing Record 22 of Set 8 | gazojak
# Processing Record 23 of Set 8 | yaan
# Processing Record 24 of Set 8 | alihe
# Processing Record 25 of Set 8 | szamotuly
# Processing Record 26 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 8 | wellington
# Processing Record 28 of Set 8 | khammam
# Processing Record 29 of Set 8 | vavatenina
# Processing Record 30 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 8 | olga
# Processing Record 32 of Set 8 | vila velha
# Processing Record 33 of Set 8 | mendi
# Processing Record 34 of Set 8 | iquitos
# Processing Record 35 of Set 8 | seymchan
# Processing Record 36 of Set 8 | ciudad bolivar
# Processing Record 37 of Set 8 | castro
# Processing Record 38 of Set 8 | nouakchott
# Processing Record 39 of Set 8 | sao jose da coroa grande
# Processing Record 40 of Set 8 | frei paulo
# Processing Record 41 of Set 8 | okato
# Processing Record 42 of Set 8 | fomboni
# Processing Record 43 of Set 8 | coihaique
# Processing Record 44 of Set 8 | ereymentau
# Processing Record 45 of Set 8 | bulawayo
# Processing Record 46 of Set 8 | vranovice
# Processing Record 47 of Set 8 | blythe
# Processing Record 48 of Set 8 | tura
# Processing Record 49 of Set 8 | axim
# Processing Record 50 of Set 8 | chimbarongo
# Processing Record 1 of Set 9 | naze
# Processing Record 2 of Set 9 | jieshi
# Processing Record 3 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 4 of Set 9 | rawson
# Processing Record 5 of Set 9 | san cristobal
# Processing Record 6 of Set 9 | naryan-mar
# Processing Record 7 of Set 9 | sadowara
# City not found. Skipping...
# Processing Record 8 of Set 9 | barranca de upia
# Processing Record 9 of Set 9 | mbekenyera
# Processing Record 10 of Set 9 | rundu
# Processing Record 11 of Set 9 | asyut
# Processing Record 12 of Set 9 | oranjemund
# Processing Record 13 of Set 9 | kupang
# Processing Record 14 of Set 9 | prainha
# Processing Record 15 of Set 9 | manubul
# Processing Record 16 of Set 9 | general roca
# Processing Record 17 of Set 9 | kirkuk
# Processing Record 18 of Set 9 | yuzawa
# Processing Record 19 of Set 9 | aklavik
# Processing Record 20 of Set 9 | baghdad
# Processing Record 21 of Set 9 | belyy yar
# Processing Record 22 of Set 9 | belmonte
# Processing Record 23 of Set 9 | notodden
# Processing Record 24 of Set 9 | vostok
# Processing Record 25 of Set 9 | jurbarkas
# Processing Record 26 of Set 9 | malakal
# Processing Record 27 of Set 9 | olds
# Processing Record 28 of Set 9 | vestmannaeyjar
# Processing Record 29 of Set 9 | faanui
# Processing Record 30 of Set 9 | berberati
# Processing Record 31 of Set 9 | phu ly
# Processing Record 32 of Set 9 | sorland
# Processing Record 33 of Set 9 | madang
# Processing Record 34 of Set 9 | willowmore
# Processing Record 35 of Set 9 | salym
# Processing Record 36 of Set 9 | ilulissat
# Processing Record 37 of Set 9 | two rivers
# Processing Record 38 of Set 9 | acarau
# Processing Record 39 of Set 9 | port elizabeth
# Processing Record 40 of Set 9 | tanabe
# Processing Record 41 of Set 9 | doha
# Processing Record 42 of Set 9 | boa vista
# Processing Record 43 of Set 9 | auki
# Processing Record 44 of Set 9 | zambezi
# Processing Record 45 of Set 9 | dire dawa
# Processing Record 46 of Set 9 | rosarito
# Processing Record 47 of Set 9 | tuensang
# Processing Record 48 of Set 9 | ovalle
# Processing Record 49 of Set 9 | najran
# Processing Record 50 of Set 9 | saquarema
# Processing Record 1 of Set 10 | tchibanga
# Processing Record 2 of Set 10 | muzhi
# Processing Record 3 of Set 10 | santiago del estero
# Processing Record 4 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 10 | palizada
# Processing Record 6 of Set 10 | homorod-de jos
# City not found. Skipping...
# Processing Record 7 of Set 10 | bijie
# Processing Record 8 of Set 10 | yerofey pavlovich
# Processing Record 9 of Set 10 | umm kaddadah
# Processing Record 10 of Set 10 | atikokan
# Processing Record 11 of Set 10 | shelburne
# Processing Record 12 of Set 10 | husavik
# Processing Record 13 of Set 10 | saint-joseph
# Processing Record 14 of Set 10 | estepa
# Processing Record 15 of Set 10 | puerto carreno
# Processing Record 16 of Set 10 | mersing
# Processing Record 17 of Set 10 | bahia de caraquez
# Processing Record 18 of Set 10 | bouca
# Processing Record 19 of Set 10 | derbent
# Processing Record 20 of Set 10 | port blair
# Processing Record 21 of Set 10 | greytown
# Processing Record 22 of Set 10 | dera din panah
# City not found. Skipping...
# Processing Record 23 of Set 10 | savannah bight
# Processing Record 24 of Set 10 | bryan
# Processing Record 25 of Set 10 | tuatapere
# Processing Record 26 of Set 10 | la ronge
# Processing Record 27 of Set 10 | thinadhoo
# Processing Record 28 of Set 10 | cotonou
# Processing Record 29 of Set 10 | inhambane
# Processing Record 30 of Set 10 | paamiut
# Processing Record 31 of Set 10 | scottsbluff
# Processing Record 32 of Set 10 | vila
# Processing Record 33 of Set 10 | anadyr
# Processing Record 34 of Set 10 | murfreesboro
# Processing Record 35 of Set 10 | vidalia
# Processing Record 36 of Set 10 | altus
# Processing Record 37 of Set 10 | saint-georges
# Processing Record 38 of Set 10 | macamic
# Processing Record 39 of Set 10 | pontianak
# Processing Record 40 of Set 10 | guozhen
# Processing Record 41 of Set 10 | maykain
# City not found. Skipping...
# Processing Record 42 of Set 10 | khomeyn
# Processing Record 43 of Set 10 | sulangan
# Processing Record 44 of Set 10 | aksarka
# Processing Record 45 of Set 10 | cururupu
# Processing Record 46 of Set 10 | tefe
# Processing Record 47 of Set 10 | escanaba
# Processing Record 48 of Set 10 | otradnoye
# Processing Record 49 of Set 10 | mareeba
# Processing Record 50 of Set 10 | forrest city
# Processing Record 1 of Set 11 | road town
# Processing Record 2 of Set 11 | herat
# Processing Record 3 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 5 of Set 11 | roma
# Processing Record 6 of Set 11 | ukiah
# Processing Record 7 of Set 11 | fairbanks
# Processing Record 8 of Set 11 | luba
# Processing Record 9 of Set 11 | praxedis guerrero
# Processing Record 10 of Set 11 | uglegorsk
# Processing Record 11 of Set 11 | torbat-e jam
# Processing Record 12 of Set 11 | murgab
# Processing Record 13 of Set 11 | fershampenuaz
# Processing Record 14 of Set 11 | walvis bay
# Processing Record 15 of Set 11 | camopi
# Processing Record 16 of Set 11 | samoylovka
# Processing Record 17 of Set 11 | puerto leguizamo
# Processing Record 18 of Set 11 | muros
# Processing Record 19 of Set 11 | grootfontein
# Processing Record 20 of Set 11 | gimli
# Processing Record 21 of Set 11 | bereda
# Processing Record 22 of Set 11 | codrington
# Processing Record 23 of Set 11 | silyanah
# City not found. Skipping...
# Processing Record 24 of Set 11 | ballina
# Processing Record 25 of Set 11 | dingle
# Processing Record 26 of Set 11 | manbij
# Processing Record 27 of Set 11 | isla mujeres
# Processing Record 28 of Set 11 | waingapu
# Processing Record 29 of Set 11 | saint-paul
# Processing Record 30 of Set 11 | guadalupe y calvo
# Processing Record 31 of Set 11 | koson
# Processing Record 32 of Set 11 | sao paulo de olivenca
# Processing Record 33 of Set 11 | riyadh
# Processing Record 34 of Set 11 | kochinda
# Processing Record 35 of Set 11 | kavaratti
# Processing Record 36 of Set 11 | koszalin
# Processing Record 37 of Set 11 | grand forks
# Processing Record 38 of Set 11 | pudem
# Processing Record 39 of Set 11 | bernau
# Processing Record 40 of Set 11 | merrill
# Processing Record 41 of Set 11 | maldonado
# Processing Record 42 of Set 11 | shwebo
# Processing Record 43 of Set 11 | salinopolis
# Processing Record 44 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 45 of Set 11 | jacareacanga
# Processing Record 46 of Set 11 | osoyoos
# Processing Record 47 of Set 11 | marsh harbour
# Processing Record 48 of Set 11 | lerwick
# Processing Record 49 of Set 11 | kaeng khoi
# Processing Record 50 of Set 11 | bilibino
# Processing Record 1 of Set 12 | birao
# Processing Record 2 of Set 12 | delta del tigre
# Processing Record 3 of Set 12 | aripuana
# Processing Record 4 of Set 12 | fuerte olimpo
# Processing Record 5 of Set 12 | afmadu
# City not found. Skipping...
# Processing Record 6 of Set 12 | jiayuguan
# Processing Record 7 of Set 12 | qasigiannguit
# Processing Record 8 of Set 12 | beberibe
# Processing Record 9 of Set 12 | gushikawa
# Processing Record 10 of Set 12 | falam
# Processing Record 11 of Set 12 | santa vitoria do palmar
# Processing Record 12 of Set 12 | lluta
# Processing Record 13 of Set 12 | nadym
# Processing Record 14 of Set 12 | santa isabel do rio negro
# Processing Record 15 of Set 12 | nuevo progreso
# Processing Record 16 of Set 12 | izumo
# Processing Record 17 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 18 of Set 12 | bensonville
# Processing Record 19 of Set 12 | villa carlos paz
# Processing Record 20 of Set 12 | monzon
# Processing Record 21 of Set 12 | kitovo
# Processing Record 22 of Set 12 | talcahuano
# Processing Record 23 of Set 12 | saint-jean-de-braye
# Processing Record 24 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 25 of Set 12 | macklin
# Processing Record 26 of Set 12 | tambovka
# Processing Record 27 of Set 12 | chapais
# Processing Record 28 of Set 12 | kerki
# City not found. Skipping...
# Processing Record 29 of Set 12 | loksa
# Processing Record 30 of Set 12 | sawakin
# Processing Record 31 of Set 12 | makhalino
# Processing Record 32 of Set 12 | mehnagar
# Processing Record 33 of Set 12 | nishihara
# Processing Record 34 of Set 12 | jinchang
# Processing Record 35 of Set 12 | aanekoski
# Processing Record 36 of Set 12 | powell river
# Processing Record 37 of Set 12 | guiyang
# Processing Record 38 of Set 12 | freeport
# Processing Record 39 of Set 12 | kasama
# Processing Record 40 of Set 12 | sabang
# Processing Record 41 of Set 12 | kodinsk
# Processing Record 42 of Set 12 | corowa
# Processing Record 43 of Set 12 | markova
# Processing Record 44 of Set 12 | kampong cham
# Processing Record 45 of Set 12 | charters towers
# Processing Record 46 of Set 12 | kachug
# Processing Record 47 of Set 12 | ovsyanka
# Processing Record 48 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 12 | san pedro
# Processing Record 50 of Set 12 | breznik
# Processing Record 1 of Set 13 | kensington
# Processing Record 2 of Set 13 | clyde river
# Processing Record 3 of Set 13 | chapleau
# Processing Record 4 of Set 13 | hansot
# Processing Record 5 of Set 13 | awbari
# Processing Record 6 of Set 13 | pacifica
# Processing Record 7 of Set 13 | guatire
# Processing Record 8 of Set 13 | yermakovskoye
# Processing Record 9 of Set 13 | souris
# Processing Record 10 of Set 13 | oktyabrskiy
# Processing Record 11 of Set 13 | labuhan
# Processing Record 12 of Set 13 | pisco
# Processing Record 13 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 13 | tevaitoa
# Processing Record 15 of Set 13 | nuremberg
# Processing Record 16 of Set 13 | quang ngai
# Processing Record 17 of Set 13 | northam
# Processing Record 18 of Set 13 | senneterre
# Processing Record 19 of Set 13 | surt
# Processing Record 20 of Set 13 | altay
# Processing Record 21 of Set 13 | ambilobe
# Processing Record 22 of Set 13 | the pas
# Processing Record 23 of Set 13 | doka
# Processing Record 24 of Set 13 | san andres
# Processing Record 25 of Set 13 | kidal
# Processing Record 26 of Set 13 | flinders
# Processing Record 27 of Set 13 | shujaabad
# Processing Record 28 of Set 13 | manacapuru
# Processing Record 29 of Set 13 | sampit
# Processing Record 30 of Set 13 | gat
# Processing Record 31 of Set 13 | tawzar
# City not found. Skipping...
# Processing Record 32 of Set 13 | maua
# Processing Record 33 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 34 of Set 13 | churachandpur
# Processing Record 35 of Set 13 | baoning
# Processing Record 36 of Set 13 | kijang
# Processing Record 37 of Set 13 | carutapera
# Processing Record 38 of Set 13 | kardasova recice
# Processing Record 39 of Set 13 | bairiki
# Processing Record 40 of Set 13 | rio grande
# Processing Record 41 of Set 13 | westport
# Processing Record 42 of Set 13 | strezhevoy
# Processing Record 43 of Set 13 | vallenar
# Processing Record 44 of Set 13 | miles city
# Processing Record 45 of Set 13 | plouzane
# Processing Record 46 of Set 13 | natchez
# Processing Record 47 of Set 13 | yarmouth
# Processing Record 48 of Set 13 | tiarei
# Processing Record 49 of Set 13 | salmas
# Processing Record 50 of Set 13 | le port
# Processing Record 1 of Set 14 | ulladulla
# Processing Record 2 of Set 14 | khani
# Processing Record 3 of Set 14 | yantal
# Processing Record 4 of Set 14 | fochville
# Processing Record 5 of Set 14 | kirakira
# Processing Record 6 of Set 14 | da lat
# Processing Record 7 of Set 14 | scaesti
# Processing Record 8 of Set 14 | malamig
# Processing Record 9 of Set 14 | watertown
# Processing Record 10 of Set 14 | fare
# Processing Record 11 of Set 14 | mwene-ditu
# Processing Record 12 of Set 14 | benghazi
# Processing Record 13 of Set 14 | belaya gora
# Processing Record 14 of Set 14 | alofi
# Processing Record 15 of Set 14 | mananjary
# Processing Record 16 of Set 14 | mahajanga
# Processing Record 17 of Set 14 | beawar
# Processing Record 18 of Set 14 | ruthen
# Processing Record 19 of Set 14 | vani
# Processing Record 20 of Set 14 | toamasina
# Processing Record 21 of Set 14 | port moresby
# Processing Record 22 of Set 14 | pitimbu
# Processing Record 23 of Set 14 | rolla
# Processing Record 24 of Set 14 | yuxia
# Processing Record 25 of Set 14 | solnechnyy
# Processing Record 26 of Set 14 | virginia beach
# Processing Record 27 of Set 14 | camapua
# Processing Record 28 of Set 14 | hambantota
# Processing Record 29 of Set 14 | kolyvan
# Processing Record 30 of Set 14 | hirado
# Processing Record 31 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 32 of Set 14 | canutama
# Processing Record 33 of Set 14 | samana
# Processing Record 34 of Set 14 | tonekabon
# Processing Record 35 of Set 14 | neuquen
# Processing Record 36 of Set 14 | ndola
# Processing Record 37 of Set 14 | burica
# City not found. Skipping...
# Processing Record 38 of Set 14 | cabatuan
# Processing Record 39 of Set 14 | nurota
# Processing Record 40 of Set 14 | smidovich
# Processing Record 41 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 42 of Set 14 | ures
# Processing Record 43 of Set 14 | burewala
# Processing Record 44 of Set 14 | tashara
# Processing Record 45 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 14 | alexandria
# Processing Record 47 of Set 14 | atar
# Processing Record 48 of Set 14 | severo-yeniseyskiy
# Processing Record 49 of Set 14 | kisangani
# Processing Record 50 of Set 14 | guamuchil
# Processing Record 1 of Set 15 | joshimath
# Processing Record 2 of Set 15 | bandar
# Processing Record 3 of Set 15 | little current
# Processing Record 4 of Set 15 | nizhniy ufaley
# Processing Record 5 of Set 15 | mombetsu
# Processing Record 6 of Set 15 | sewon
# Processing Record 7 of Set 15 | tahe
# Processing Record 8 of Set 15 | chifeng
# Processing Record 9 of Set 15 | shache
# Processing Record 10 of Set 15 | shrewsbury
# Processing Record 11 of Set 15 | atka
# City not found. Skipping...
# Processing Record 12 of Set 15 | nehe
# Processing Record 13 of Set 15 | veinticinco de mayo
# Processing Record 14 of Set 15 | urusha
# Processing Record 15 of Set 15 | pemberton
# Processing Record 16 of Set 15 | lodja
# Processing Record 17 of Set 15 | bandar-e lengeh
# Processing Record 18 of Set 15 | nuuk
# Processing Record 19 of Set 15 | progreso
# Processing Record 20 of Set 15 | waipawa
# Processing Record 21 of Set 15 | darab
# Processing Record 22 of Set 15 | deloraine
# Processing Record 23 of Set 15 | moerai
# Processing Record 24 of Set 15 | bajil
# Processing Record 25 of Set 15 | alekseyevsk
# Processing Record 26 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 15 | udachnyy
# Processing Record 28 of Set 15 | yanam
# Processing Record 29 of Set 15 | contamana
# Processing Record 30 of Set 15 | angelholm
# City not found. Skipping...
# Processing Record 31 of Set 15 | alta floresta
# Processing Record 32 of Set 15 | seoni
# Processing Record 33 of Set 15 | elko
# Processing Record 34 of Set 15 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 35 of Set 15 | parsabad
# Processing Record 36 of Set 15 | sumoto
# Processing Record 37 of Set 15 | abu zabad
# Processing Record 38 of Set 15 | pangkalanbuun
# Processing Record 39 of Set 15 | aleksandrovsk-sakhalinskiy
# Processing Record 40 of Set 15 | ndele
# Processing Record 41 of Set 15 | marsa matruh
# Processing Record 42 of Set 15 | kaeo
# Processing Record 43 of Set 15 | never
# Processing Record 44 of Set 15 | krasnoyarka
# Processing Record 45 of Set 15 | kapuskasing
# Processing Record 46 of Set 15 | lake havasu city
# Processing Record 47 of Set 15 | luganville
# Processing Record 48 of Set 15 | sumbawa
# City not found. Skipping...
# Processing Record 49 of Set 15 | raudeberg
# Processing Record 50 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 1 of Set 16 | san rafael
# Processing Record 2 of Set 16 | jega
# Processing Record 3 of Set 16 | benidorm
# Processing Record 4 of Set 16 | buala
# Processing Record 5 of Set 16 | turka
# Processing Record 6 of Set 16 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 16 | eyrarbakki
# Processing Record 8 of Set 16 | morada nova
# Processing Record 9 of Set 16 | pandan
# Processing Record 10 of Set 16 | sorong
# Processing Record 11 of Set 16 | bumbuna
# Processing Record 12 of Set 16 | zyryanka
# Processing Record 13 of Set 16 | guangyuan
# Processing Record 14 of Set 16 | dunedin
# Processing Record 15 of Set 16 | azovo
# Processing Record 16 of Set 16 | mocambique
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Aykhal      RU  66.0000  111.5000     30.74        97         100
# 1       Avarua      CK -21.2078 -159.7750     82.45        74          75
# 2    Ust-Kuyga      RU  70.0167  135.6000     14.94        84          96
# 3    Morondava      MG -20.2833   44.2833     77.59        92           2
# 4  Tuktoyaktuk      CA  69.4541 -133.0374      0.55        91          51
# 5      Mataura      NZ -46.1927  168.8643     53.47        46          99
# 6  Yellowknife      CA  62.4560 -114.3525      3.20        90         100
# 7   Georgetown      MY   5.4112  100.3354     89.53        70          20
# 8       Cuamba      MZ -14.8031   36.5372     65.39        99          15
# 9         Hilo      US  19.7297 -155.0900     73.27        92         100
#
#    Wind Speed Current Description
# 0       15.12                snow
# 1       10.36       broken clouds
# 2        6.78     overcast clouds
# 3        5.95           clear sky
# 4        5.82       broken clouds
# 5        3.49     overcast clouds
# 6        5.55     overcast clouds
# 7        3.44          few clouds
# 8        3.24          few clouds
# 9        5.75       moderate rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
